# %% [markdown]
# <a href="https://colab.research.google.com/github/Faiqazmi/DataScience_Portofolio/blob/main/Project_Zakat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **sesuai dengan goals, berikut:**
# 1. Forecasting
# 2. Dashboard
# 3. Analytical Insight
#
# **Objektif pengerjaan dataset yang bisa teman-teman perhatikan sebagai berikut:**
#
# 1. Data Understanding
# 2. Data Preparation
# 3. Data Analyst (Insight)
# 4. Data Pre-Processing
# 5. Data Modelling (Forecasting)
# 6. Data Visualisasi (Dashboard - Google Data Studio)

# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hardiawan3010/datase_zakat/main/zakat.csv', delimiter=',')
df
# Out:
#        ID                        name  ... metode_pembayaran         Class
# 0    2689  Dirga Imam Gozali Sumantri  ...          echannel   Zakat_user
# 1    2690    Putu Berly Calvina Izumi  ...     bank_transfer   Zakat_user
# 2    2691          Pak Saeful Rokhman  ...  BCA - 1393004952   Zakat_user
# 3    2692    Vinanda Langgeng Kencana  ...  BCA - 1393040002   Zakat_user
# 4    2693                      Novias  ...  BCA - 1393040002   Zakat_user
# ..    ...                         ...  ...               ...           ...
# 670  4019           Fraskatia Syahrin  ...           MANDIRI  zakat_guest
# 671  4028       Dinar Swastika Ardias  ...     bank_transfer  zakat_guest
# 672  4029                 Hamba Allah  ...     bank_transfer  zakat_guest
# 673  4030                 Hamba Allah  ...     bank_transfer  zakat_guest
# 674  4033                       ninis  ...           MANDIRI  zakat_guest
#
# [675 rows x 9 columns]

# %%
user = df[df['Class'] == 'Zakat_user ']
user
# Out:
#        ID                        name  ...        metode_pembayaran        Class
# 0    2689  Dirga Imam Gozali Sumantri  ...                 echannel  Zakat_user
# 1    2690    Putu Berly Calvina Izumi  ...            bank_transfer  Zakat_user
# 2    2691          Pak Saeful Rokhman  ...         BCA - 1393004952  Zakat_user
# 3    2692    Vinanda Langgeng Kencana  ...         BCA - 1393040002  Zakat_user
# 4    2693                      Novias  ...         BCA - 1393040002  Zakat_user
# ..    ...                         ...  ...                      ...          ...
# 332  4031                 Fara Kirana  ...         BCA - 1393004952  Zakat_user
# 333  4032   Libonit Poetry Mayangsari  ...         BCA - 1393040002  Zakat_user
# 334  4034              Nike Pudjiwati  ...         BCA - 1393040002  Zakat_user
# 335  4035               Helena Shinta  ...  Mandiri - 1010012312318  Zakat_user
# 336  4036               Ima Gusnandar  ...  Mandiri - 1320006531140  Zakat_user
#
# ...

# %%
guest = df[df['Class'] == 'zakat_guest ']
guest
# Out:
#        ID                        name  ... metode_pembayaran         Class
# 337  2702  Muhammad Ramadhan Alkausar  ...             gopay  zakat_guest
# 338  2704         Muhamad Haris Yahya  ...     bank_transfer  zakat_guest
# 339  2710       Karunia Erldi Abraham  ...     bank_transfer  zakat_guest
# 340  2718                Irma Suryati  ...          echannel  zakat_guest
# 341  2739     Arriman Maulana Makmoen  ...     bank_transfer  zakat_guest
# ..    ...                         ...  ...               ...           ...
# 670  4019           Fraskatia Syahrin  ...           MANDIRI  zakat_guest
# 671  4028       Dinar Swastika Ardias  ...     bank_transfer  zakat_guest
# 672  4029                 Hamba Allah  ...     bank_transfer  zakat_guest
# 673  4030                 Hamba Allah  ...     bank_transfer  zakat_guest
# 674  4033                       ninis  ...           MANDIRI  zakat_guest
#
# [338 rows x 9 columns]

# %%
df.dtypes
# Out:
# ID                     int64
# name                  object
# platform              object
# category              object
# tanggal               object
# total_zakat          float64
# status                object
# metode_pembayaran     object
# Class                 object
# dtype: object

# %%
df.describe()
# Out:
#                 ID   total_zakat
# count   675.000000  6.750000e+02
# mean   3397.842963  4.379380e+05
# std     404.289415  1.201925e+06
# min    2689.000000  1.000000e+00
# 25%    3074.000000  5.000000e+04
# 50%    3432.000000  1.500000e+05
# 75%    3742.500000  3.475000e+05
# max    4036.000000  1.162500e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 675 non-null    int64
#  1   name               675 non-null    object
#  2   platform           674 non-null    object
#  3   category           675 non-null    object
#  4   tanggal            675 non-null    object
#  5   total_zakat        675 non-null    float64
#  6   status             675 non-null    object
#  7   metode_pembayaran  675 non-null    object
#  8   Class              675 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 47.6+ KB

# %%
df.duplicated().value_counts()
# Out:
# False    675
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# settlement    669
# COMPLETED       4
# PAID            2
# Name: status, dtype: int64

# %%
df['category'].value_counts()
# Out:
# Zakat Penghasilan    358
# Zakat Fitrah         258
# Zakat Harta           55
# Zakat Emas             4
# Name: category, dtype: int64

# %%
# banyaknya data berdasarakan metode pembayaran
df['metode_pembayaran'].value_counts()
# Out:
# bank_transfer                                 254
# MANDIRI                                        97
# BCA - 1393040002                               70
# BNI                                            35
# BRI                                            33
# gopay                                          32
# BCA - 1393004952                               24
# Mandiri - 1320006531140                        19
# Mandiri - 1320505050519                        17
# Mandiri - 1320020040060                        16
# echannel                                       15
# Transfer Bank Mandiri Syariah - 7273737377     13
# BRI - 013701000379303                           6
# Mandiri Syariah - 7273737377                    6
# Mandiri - 1010012312318                         5
# Mandiri Syariah - 7277777775                    5
# credit_card                                     4
# OVO                                             4
# PERMATA                                         3
# ...

# %%
#cek missing value
df.isnull().sum()
# Out:
# ID                   0
# name                 0
# platform             1
# category             0
# tanggal              0
# total_zakat          0
# status               0
# metode_pembayaran    0
# Class                0
# dtype: int64

# %%
#isi missing value dengan forward fill
df= df.ffill()

# %%
df.isnull().sum()
# Out:
# ID                   0
# name                 0
# platform             0
# category             0
# tanggal              0
# total_zakat          0
# status               0
# metode_pembayaran    0
# Class                0
# dtype: int64

# %%
# rapihin kolom metode pembayaran
df.loc[:,["metode_pembayaran"]]=df["metode_pembayaran"].str.lower()
daftar_singkatan=['yayasan mizan amanah', 'mizan amanah', 'transfer', 'bank', '1', '2', '3', '4', '5', '6', '7', '8', '9', '0','syariah', '_va','-', 'gani',' ',
                  '_donation', '_card']

for i in daftar_singkatan:
  df.loc[:,["metode_pembayaran"]]=df["metode_pembayaran"].str.replace(i, '', regex=False)
  
df.loc[:,["metode_pembayaran"]]=df["metode_pembayaran"].str.replace('_', 'bank lainnya', regex=False)
df['metode_pembayaran'].value_counts()
# Out:
# bank lainnya    254
# mandiri         186
# bca              95
# bri              39
# bni              36
# gopay            32
# echannel         15
# muamalat          4
# ovo               4
# credit            4
# permata           3
# dana              2
# creditcard        1
# Name: metode_pembayaran, dtype: int64

# %%
# lowercase kolom name
df.loc[:,["name"]]=df["name"].str.lower()
df.head(3)
# Out:
#      ID                        name  ... metode_pembayaran        Class
# 0  2689  dirga imam gozali sumantri  ...          echannel  Zakat_user
# 1  2690    putu berly calvina izumi  ...      bank lainnya  Zakat_user
# 2  2691          pak saeful rokhman  ...               bca  Zakat_user
#
# [3 rows x 9 columns]

# %%
# lowercase kolom platform
df.loc[:,["platform"]]=df["platform"].str.lower()
df.head(3)
# Out:
#      ID                        name  ... metode_pembayaran        Class
# 0  2689  dirga imam gozali sumantri  ...          echannel  Zakat_user
# 1  2690    putu berly calvina izumi  ...      bank lainnya  Zakat_user
# 2  2691          pak saeful rokhman  ...               bca  Zakat_user
#
# [3 rows x 9 columns]

# %%
df['Class'].value_counts()
# Out:
# zakat_guest     338
# Zakat_user      337
# Name: Class, dtype: int64

# %%
df['metode_pembayaran'].value_counts()
# Out:
# bank lainnya    254
# mandiri         186
# bca              95
# bri              39
# bni              36
# gopay            32
# echannel         15
# muamalat          4
# ovo               4
# credit            4
# permata           3
# dana              2
# creditcard        1
# Name: metode_pembayaran, dtype: int64

# %%
df['name'].value_counts()
# Out:
# hamba allah              29
# eli laili yanah           8
# anggun hidayatullah       7
# alivia rizky ariyanti     7
# fadillah                  6
#                          ..
# rachmat mulyadi           1
# dias darmawan             1
# dikdik permadi            1
# yuhana robina             1
# aryanahardi               1
# Name: name, Length: 469, dtype: int64

# %% [markdown]
# # visualisasi

# %%
a= df['category'].value_counts()
b= a.index
plt.bar(b,a, color='green')
plt.title('Kategori')
# Out:
# Text(0.5, 1.0, 'Kategori')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
a= df['platform'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Platform')


plt.subplot(2, 2, 2)
a= df['status'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Status Pembayaran')

plt.figure (figsize=(70,15))
plt.subplot(2, 2, 3)
a= df['metode_pembayaran'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Status Pembayaran')
# Out:
# Text(0.5, 1.0, 'Status Pembayaran')

# %%
# Berdasarkan tiap tiap kolom
plt.figure(figsize=(20, 30)) # Membuat ukuran 
plt.subplot(2, 2, 1) #2 baris, 3 kolom, plot 1
data = df['Class'].value_counts()
label = data.index

plt.pie(data, labels=label, autopct='%.2f%%')
plt.title('Class')

plt.show()

# %%
df
# Out:
#        ID                        name  ... metode_pembayaran         Class
# 0    2689  dirga imam gozali sumantri  ...          echannel   Zakat_user
# 1    2690    putu berly calvina izumi  ...      bank lainnya   Zakat_user
# 2    2691          pak saeful rokhman  ...               bca   Zakat_user
# 3    2692    vinanda langgeng kencana  ...               bca   Zakat_user
# 4    2693                      novias  ...               bca   Zakat_user
# ..    ...                         ...  ...               ...           ...
# 670  4019           fraskatia syahrin  ...           mandiri  zakat_guest
# 671  4028       dinar swastika ardias  ...      bank lainnya  zakat_guest
# 672  4029                 hamba allah  ...      bank lainnya  zakat_guest
# 673  4030                 hamba allah  ...      bank lainnya  zakat_guest
# 674  4033                       ninis  ...           mandiri  zakat_guest
#
# [675 rows x 9 columns]

# %% [markdown]
# # data preparation

# %%
dade = pd.read_csv('https://raw.githubusercontent.com/hardiawan3010/datase_zakat/main/zakat.csv',parse_dates = ['tanggal'], index_col=['tanggal'])
dade
# Out:
#                        ID  ...         Class
# tanggal                    ...
# 2021-01-01 13:03:30  2689  ...   Zakat_user
# 2021-01-04 00:55:12  2690  ...   Zakat_user
# 2021-01-04 08:43:51  2691  ...   Zakat_user
# 2021-01-04 08:50:12  2692  ...   Zakat_user
# 2021-01-04 09:41:49  2693  ...   Zakat_user
# ...                   ...  ...           ...
# 2021-11-30 13:10:03  4019  ...  zakat_guest
# 2021-12-02 21:06:24  4028  ...  zakat_guest
# 2021-12-02 23:12:32  4029  ...  zakat_guest
# 2021-12-02 23:16:33  4030  ...  zakat_guest
# 2021-12-03 13:53:49  4033  ...  zakat_guest
#
# [675 rows x 8 columns]

# %%
data = df.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 675 non-null    int64
#  1   name               675 non-null    object
#  2   platform           675 non-null    object
#  3   category           675 non-null    object
#  4   tanggal            675 non-null    object
#  5   total_zakat        675 non-null    float64
#  6   status             675 non-null    object
#  7   metode_pembayaran  675 non-null    object
#  8   Class              675 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 47.6+ KB

# %%
col = ['ID', 'name', 'platform', 'category', 'status', 'metode_pembayaran', 'Class']
data = data.drop(col, axis =1)
data
# Out:
#                  tanggal  total_zakat
# 0    2021-01-01 13:03:30    6000000.0
# 1    2021-01-04 00:55:12     100000.0
# 2    2021-01-04 08:43:51     300000.0
# 3    2021-01-04 08:50:12    1000000.0
# 4    2021-01-04 09:41:49      55000.0
# ..                   ...          ...
# 670  2021-11-30 13:10:03     150000.0
# 671  2021-12-02 21:06:24     345000.0
# 672  2021-12-02 23:12:32     350000.0
# 673  2021-12-02 23:16:33     480000.0
# 674  2021-12-03 13:53:49     213000.0
#
# [675 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tanggal      675 non-null    object
#  1   total_zakat  675 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.7+ KB

# %%
data['tanggal'] = pd.to_datetime(data['tanggal'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tanggal      675 non-null    datetime64[ns]
#  1   total_zakat  675 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 10.7 KB

# %%
data['date'] = pd.to_datetime(data['tanggal']).dt.date
data
# Out:
#                 tanggal  total_zakat        date
# 0   2021-01-01 13:03:30    6000000.0  2021-01-01
# 1   2021-01-04 00:55:12     100000.0  2021-01-04
# 2   2021-01-04 08:43:51     300000.0  2021-01-04
# 3   2021-01-04 08:50:12    1000000.0  2021-01-04
# 4   2021-01-04 09:41:49      55000.0  2021-01-04
# ..                  ...          ...         ...
# 670 2021-11-30 13:10:03     150000.0  2021-11-30
# 671 2021-12-02 21:06:24     345000.0  2021-12-02
# 672 2021-12-02 23:12:32     350000.0  2021-12-02
# 673 2021-12-02 23:16:33     480000.0  2021-12-02
# 674 2021-12-03 13:53:49     213000.0  2021-12-03
#
# [675 rows x 3 columns]

# %%
del data['tanggal']

# %%
data
# Out:
#      total_zakat        date
# 0      6000000.0  2021-01-01
# 1       100000.0  2021-01-04
# 2       300000.0  2021-01-04
# 3      1000000.0  2021-01-04
# 4        55000.0  2021-01-04
# ..           ...         ...
# 670     150000.0  2021-11-30
# 671     345000.0  2021-12-02
# 672     350000.0  2021-12-02
# 673     480000.0  2021-12-02
# 674     213000.0  2021-12-03
#
# [675 rows x 2 columns]

# %% [markdown]
# # ARIMA

# %%
train=data.iloc[:550]
test=data.iloc[540:]

train
# Out:
#                 tanggal  total_zakat
# 0   2021-01-01 13:03:30    6000000.0
# 1   2021-01-04 00:55:12     100000.0
# 2   2021-01-04 08:43:51     300000.0
# 3   2021-01-04 08:50:12    1000000.0
# 4   2021-01-04 09:41:49      55000.0
# ..                  ...          ...
# 545 2021-05-13 00:12:38     175000.0
# 546 2021-05-13 00:13:26      97500.0
# 547 2021-05-13 00:14:08      40000.0
# 548 2021-05-13 00:17:48      40000.0
# 549 2021-05-13 01:00:37      22500.0
#
# [550 rows x 2 columns]

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(train['total_zakat'],order=(1,1,1)) # (p -> AR, d -> I (stationarity) , q -> MA)
results=model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
# predictions
predictions=results.predict(start,end,typ='levels').rename('ARIMA(1,1,1) Predictions')

# %%
test['total_zakat'].plot(legend=True)
predictions.plot(legend=True)

# %%
col = ['ID', 'name', 'platform', 'category', 'status', 'metode_pembayaran', 'Class']
dade = dade.drop(col, axis =1)
dade
# Out:
#                      total_zakat
# tanggal
# 2021-01-01 13:03:30    6000000.0
# 2021-01-04 00:55:12     100000.0
# 2021-01-04 08:43:51     300000.0
# 2021-01-04 08:50:12    1000000.0
# 2021-01-04 09:41:49      55000.0
# ...                          ...
# 2021-11-30 13:10:03     150000.0
# 2021-12-02 21:06:24     345000.0
# 2021-12-02 23:12:32     350000.0
# 2021-12-02 23:16:33     480000.0
# 2021-12-03 13:53:49     213000.0
#
# [675 rows x 1 columns]

# %%
dade = dade.resample('W').sum()
dade.head()
# Out:
#             total_zakat
# tanggal
# 2021-01-03    6000000.0
# 2021-01-10   15622732.0
# 2021-01-17    3305500.0
# 2021-01-24    5900000.0
# 2021-01-31   13883413.0

# %%
import matplotlib.pyplot as plt

dade.plot(figsize = (20, 6))
plt.ylabel('Total_Donasi')
plt.title('guest per day')
# Out:
# Text(0.5, 1.0, 'guest per day')

# %% [markdown]
# # Simple Moving Average

# %%
#simple moving average
dade['total_zakat'].rolling(6).mean().plot(label = '6 month SMA', figsize = (20,6))
dade['total_zakat'].rolling(12).mean().plot(label = '12 month SMA' )
plt.legend()

# %% [markdown]
# # Simple Exponential Smoothing

# %%
# Simple Exponential Smoothing
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

df_ses = dade.copy()

model_ses = SimpleExpSmoothing(dade['total_zakat'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) # bisa masukin alpha
df_ses['SES'] = fitted_model_ses.fittedvalues

df_ses.head(20)
# Out:
#             total_zakat           SES
# tanggal
# 2021-01-03    6000000.0  6.000000e+06
# 2021-01-10   15622732.0  6.000000e+06
# 2021-01-17    3305500.0  8.886820e+06
# 2021-01-24    5900000.0  7.212424e+06
# 2021-01-31   13883413.0  6.818697e+06
# 2021-02-07    4526000.0  8.938112e+06
# 2021-02-14   12920000.0  7.614478e+06
# 2021-02-21    2250000.0  9.206135e+06
# 2021-02-28   13073454.0  7.119294e+06
# 2021-03-07    5857850.0  8.905542e+06
# 2021-03-14     295458.0  7.991235e+06
# 2021-03-21    5500000.0  5.682502e+06
# 2021-03-28    3211816.0  5.627751e+06
# 2021-04-04    2207500.0  4.902971e+06
# 2021-04-11     670000.0  4.094329e+06
# 2021-04-18    1000000.0  3.067031e+06
# 2021-04-25    1803750.0  2.446921e+06
# 2021-05-02    3190009.0  2.253970e+06
# 2021-05-09   18646627.0  2.534782e+06
# 2021-05-16   57321468.0  7.368335e+06

# %%
df_ses.plot()

# %%
# Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df_es = data.copy()

model = ExponentialSmoothing(data['total_zakat'], trend = 'add') # try mul
fitted_model = model.fit()
df_es['ES'] = fitted_model.fittedvalues.shift(-1)

df_es.head(20)

# %%
df_es.plot()

# %%
train_data = dade.iloc[:325] # df.loc[:'1940-01-01']
test_data = dade.iloc[325:]

# %%
fitted_model = ExponentialSmoothing(train_data['total_zakat'],
                                   trend = 'add', # try mul
                                   seasonal = 'add', # try mul
                                   seasonal_periods = 20).fit()

# %%
test_predictions = fitted_model.forecast(325)

# %%
train_data['total_zakat'].plot(legend=True, label = 'Train',
                             figsize = (12,5))
test_data['total_zakat'].plot(legend=True, label = 'Test')
test_predictions.plot(legend=True, label = 'Prediction')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-197-367c2da70dbb> in <module>()
#       1 train_data['total_zakat'].plot(legend=True, label = 'Train',
#       2                              figsize = (12,5))
# ----> 3 test_data['total_zakat'].plot(legend=True, label = 'Test')
#       4 test_predictions.plot(legend=True, label = 'Prediction')
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_zakat'],test_predictions[:10]))
print("MSE: ",mean_squared_error(test_data['total_zakat'],test_predictions[:10]))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_zakat'],test_predictions[:10])))
print("R2: ",r2_score(test_data['total_zakat'],test_predictions[:10]))
print("")

# %% [markdown]
# # coba ml

# %%
df_ml = data.copy()
df_ml.drop(['date'], axis=1, inplace=True)
df_ml.head()
# Out:
#    total_zakat
# 0    6000000.0
# 1     100000.0
# 2     300000.0
# 3    1000000.0
# 4      55000.0

# %%
#lagged Function, just copas from 
#https://stackoverflow.com/questions/20410312/how-to-create-a-lagged-data-structure-using-pandas-dataframe
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag1 = LaggedFeatures(df_ml,lag=3,fillna=True, dropna=True)
lag1.shape
# Out:
# (672, 4)

# %%
train = lag1.iloc[:500]
test = lag1.iloc[500:]
train
# Out:
#      total_zakat  total_zakat_lag1  total_zakat_lag2  total_zakat_lag3
# 3      1000000.0          300000.0          100000.0         6000000.0
# 4        55000.0         1000000.0          300000.0          100000.0
# 5       117500.0           55000.0         1000000.0          300000.0
# 6      3000000.0          117500.0           55000.0         1000000.0
# 7        80000.0         3000000.0          117500.0           55000.0
# ..           ...               ...               ...               ...
# 498      37500.0           80000.0           35000.0           50000.0
# 499     120000.0           37500.0           80000.0           35000.0
# 500      80000.0          120000.0           37500.0           80000.0
# 501     120000.0           80000.0          120000.0           37500.0
# 502      40000.0          120000.0           80000.0          120000.0
#
# [500 rows x 4 columns]

# %%
#create X and y

X_train = train.drop(['total_zakat'], axis=1)
X_test = test.drop(['total_zakat'], axis=1)

y_train = train['total_zakat']
y_test = test ['total_zakat']


X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
# call model
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor()
lr = LinearRegression()

#train
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np


y_pred_rf = rf.predict(X_test)
y_pred_lr = lr.predict(X_test)


print("Random Forest Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
print("MSE: ",mean_squared_error(y_test,y_pred_rf))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("R2: ",r2_score(y_test,y_pred_rf))
print("")

print("Linear Regression")
print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
print("MSE: ",mean_squared_error(y_test,y_pred_lr))
print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
print("R2: ",r2_score(y_test,y_pred_lr))
print("")
# Out:
# Random Forest Regression
# MAE:  424860.2736137119
# MSE:  843772715355.3768
# RMSE:  918571.018133806
# R2:  -1.7257721911037347
#
# Linear Regression
# MAE:  463911.9158711286
# MSE:  416741987966.6352
# RMSE:  645555.565359509
# R2:  -0.34626742604056493

# %%
#Plot untuk melihat hasil
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(18,6)) 

axs[0].plot(y_test,label='real values')
axs[0].plot(y_pred_rf,label='predicted values')
axs[0].set_title("Random Forest")
axs[0].legend()

axs[1].plot(y_test,label='real values')
axs[1].plot(y_pred_lr,label='predicted values')
axs[1].set_title("Linear Regression")
axs[1].legend()

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
df_1 = pd.read_csv('https://raw.githubusercontent.com/hardiawan3010/datase_zakat/main/zakat.csv', delimiter=',', parse_dates = ['tanggal'], index_col = ['tanggal'])
df_1
# Out:
#                        ID  ...         Class
# tanggal                    ...
# 2021-01-01 13:03:30  2689  ...   Zakat_user
# 2021-01-04 00:55:12  2690  ...   Zakat_user
# 2021-01-04 08:43:51  2691  ...   Zakat_user
# 2021-01-04 08:50:12  2692  ...   Zakat_user
# 2021-01-04 09:41:49  2693  ...   Zakat_user
# ...                   ...  ...           ...
# 2021-11-30 13:10:03  4019  ...  zakat_guest
# 2021-12-02 21:06:24  4028  ...  zakat_guest
# 2021-12-02 23:12:32  4029  ...  zakat_guest
# 2021-12-02 23:16:33  4030  ...  zakat_guest
# 2021-12-03 13:53:49  4033  ...  zakat_guest
#
# [675 rows x 8 columns]

# %%
df_lstm = df_1.copy()
df_lstm.drop(['ID', 'name','platform','category', 'status', 'metode_pembayaran', 'Class'], axis=1, inplace=True)
df_lstm
# Out:
#                      total_zakat
# tanggal
# 2021-01-01 13:03:30    6000000.0
# 2021-01-04 00:55:12     100000.0
# 2021-01-04 08:43:51     300000.0
# 2021-01-04 08:50:12    1000000.0
# 2021-01-04 09:41:49      55000.0
# ...                          ...
# 2021-11-30 13:10:03     150000.0
# 2021-12-02 21:06:24     345000.0
# 2021-12-02 23:12:32     350000.0
# 2021-12-02 23:16:33     480000.0
# 2021-12-03 13:53:49     213000.0
#
# [675 rows x 1 columns]

# %%
df_lstm = df_lstm.resample('D').sum()
df_lstm
# Out:
#             total_zakat
# tanggal
# 2021-01-01    6000000.0
# 2021-01-02          0.0
# 2021-01-03          0.0
# 2021-01-04    7127500.0
# 2021-01-05     650000.0
# ...                 ...
# 2021-12-01    1929000.0
# 2021-12-02    1845000.0
# 2021-12-03     963000.0
# 2021-12-04     100000.0
# 2021-12-05     900000.0
#
# [339 rows x 1 columns]

# %%
train_df = df_lstm[:len(df_lstm)-12]
test_df = df_lstm[len(df_lstm)-12:]

# %%
df_lstm
# Out:
#             total_zakat
# tanggal
# 2021-01-01    6000000.0
# 2021-01-02          0.0
# 2021-01-03          0.0
# 2021-01-04    7127500.0
# 2021-01-05     650000.0
# ...                 ...
# 2021-12-01    1929000.0
# 2021-12-02    1845000.0
# 2021-12-03     963000.0
# 2021-12-04     100000.0
# 2021-12-05     900000.0
#
# [339 rows x 1 columns]

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)
train = scaler.transform(train_df)
test = scaler.transform(test_df)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(400, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=50, verbose= 0)
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 400)               643200
#
#  dropout_1 (Dropout)         (None, 400)               0
#
#  dense_1 (Dense)             (None, 1)                 401
#
# ...
# Total params: 643,601
# Trainable params: 643,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=df_lstm[-n_input:].index, columns=['Prediction'])
df_test = pd.concat([df_lstm,df_predict], axis=1)

# %%
df_test.tail(15)
# Out:
#             total_zakat     Prediction
# tanggal
# 2021-11-21          0.0            NaN
# 2021-11-22     150000.0            NaN
# 2021-11-23          0.0            NaN
# 2021-11-24     380275.0  297020.806254
# 2021-11-25     601698.0  329237.881063
# 2021-11-26    2911250.0  373691.656455
# 2021-11-27    1050000.0  406982.311114
# 2021-11-28     300000.0  386256.536938
# 2021-11-29    1100000.0  361964.669604
# 2021-11-30     350000.0  340116.096816
# 2021-12-01    1929000.0  389485.099806
# 2021-12-02    1845000.0  484084.547909
# 2021-12-03     963000.0  492135.092901
# 2021-12-04     100000.0  498366.211717
# 2021-12-05     900000.0  506101.098813

# %%
print("LSTM")
print("MAE: ",mean_absolute_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("MSE: ",mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("RMSE: ", np.sqrt(mean_squared_error(df_test.iloc[-12:,0],df_test.iloc[-12:,1])))
print("R2: ",r2_score(df_test.iloc[-12:,0],df_test.iloc[-12:,1]))
print("")
# Out:
# LSTM
# MAE:  711168.8739934461
# MSE:  1020319720192.9525
# RMSE:  1010108.7665162364
# R2:  -0.6317303228675841

# %%
plt.figure(figsize=(27, 8))
plt.plot(df_test.index, df_test['total_zakat'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
col = ['ID', 'name', 'platform', 'category', 'status', 'metode_pembayaran', 'Class']

guest = guest.drop(col, axis=1)
guest

# %%
guest.info()

# %%
guest.plot(figsize=(20,10))

# %%
guest.index.value_counts()

# %%
guestc = guest.copy()
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(guestc['total_zakat']) #data_wide is table name

# %%
guestc['total_zakat'] = guestc['total_zakat'].reshape(-1,1)

# %%
guest['date'] = pd.to_datetime(df[index]).dt.date
guest['waktu'] = pd.to_datetime(df[index]).dt.time

# %%
df

# %%
df

# %%
df['Tanggal'].duplicated().value_counts()

# %%
df['Tanggal'].value_counts()

# %%
df['Class'].value_counts()

# %%
df['category'].value_counts()

# %%
df['status'].value_counts()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2, 3, 2)
a= df['platform'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Platform')

plt.subplot(2, 3, 1) #2 baris, 3 kolom, plot 1
a= df['category'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Kategori')

plt.subplot(2, 3, 3)
a= df['status'].value_counts()
b= a.index
plt.bar(b,a, color='lightcoral')
plt.title('Status Pembayaran')

# %%
df_t= df['Tanggal'].value_counts()
df_t

# %%
a= df['Tanggal']
b= df['Tanggal'].index
plt.plot(a,b)

# %%
plt.figure(figsize=(15, 7)) 
data = df['Class'].value_counts()
label = data.index

plt.pie(data, labels=label, autopct='%.2f%%', explode=(0.05,0))
plt.title('Keterangan')

# %%
#berdasarkan kelas
f, axes = plt.subplots(1,2, figsize=(13, 6))
df['platform'].value_counts().plot(kind='pie',ax=axes[0], title='Zakat_users', autopct='%1.1f%%', shadow=True)
df['platform'].value_counts().plot(kind='pie',ax=axes[1], title='zakat_guest', autopct='%1.1f%%', shadow=True)

plt.tight_layout()
plt.show()

# %%
#  f, axes = plt.subplots(1,2, figsize=(15, 20))
a,axes = plt.subplots(1,2, figsize=(15, 15))
df['status'].value_counts().plot(kind='pie',ax=axes[0], title='Zakat_users', autopct='%1.1f%%')
df['status'].value_counts().plot(kind='pie',ax=axes[1], title='zakat_guest', autopct='%1.1f%%')

plt.tight_layout()
plt.show()

# %%
df_edit = df.copy(deep=True)
df_edit.category = df_edit['category'].map({'Zakat Penghasilan':0, 'Zakat Fitrah':1, 'Zakat Harta':2, 'Zakat Emas':3})
# df_edit.sex = df_edit['sex'].map({0:'Wanita', 1:'Pria'})
# df_edit.cp = df_edit['cp'].map({0:'Typical angina', 1:'Atypical angina', 2 :'Non-anginal pain', 3:'Asymptomatic'})
# df_edit.fbs = df_edit['fbs'].map({0:'fbs<=120', 1:'Fbs>120'})
# df_edit.restecg = df_edit['restecg'].map({0:'Normal', 1:'Abnormal', 2:'Hypertrofi ventrikel'})
# df_edit.exang = df_edit['exang'].map({0:'Tidak', 1:'Iya'})
# df_edit.slope = df_edit['slope'].map({0:'UpSloping', 1:'FlatSloping', 2:'DownSloping'})
# df_edit.ca = df_edit['ca'].map({0:'Tidak', 1:'Iya'})
# df_edit.thal = df_edit['thal'].map(lambda x: 'normal' if x==0 or x==1 else ('rever' if x==2 else ('fixed')))
# Zakat Penghasilan    358
# Zakat Fitrah         258
# Zakat Harta           55
# Zakat Emas

# %%
df_edit.info()

# %%
df[['category', 'status']] = df[['category', 'status']].astype("object")

# %%
df.info()

# %%
df

# %%
id_nama=pd.DataFrame(df.Tanggal.unique()).reset_index().rename({0: 'a', 'index':'b'}, axis=1)
id_nama

# %%
df3 = df['Tanggal'].value_counts().rename_axis('Tanggal').reset_index(name='jumlah')
df3

# %%
df3['Tanggal'] = pd.to_datetime(df.Tanggal)
print (df3)

# %%
df3.info()

# %%
tgl = df['Tanggal'].value_counts()
df2 = pd.DataFrame(df['Tanggal'], tgl)
df2

# %%
df2.info()

# %%
tgl = df['Tanggal'].value_counts()
df1 = df['total_zakat']
df1 = pd.DataFrame(df1,tgl)
df1.plot()

# %%
z = dF['tanggal']
x = dF['total_zakat']
df.plot(x,z)

# %%
dfs = dF['tanggal']
dfg = dfs.value_counts()
df.plot(dfs, dfg)

# %%
# Simple Moving Average
df_sma = df2.copy()
df_sma['6-month-SMA'] = data[' '].rolling(window=6).mean()
df_sma['12-month-SMA'] = data[' '].rolling(window=12).mean()
df_sma.head(20)

# %%
import seaborn as sns

plt.figure(figsize=(15, 12))
sns.heatmap(df.corr(), annot=True, cmap='Spectral')
plt.title("Heatmap", fontsize = 25)
plt.show()

# %%
# df.to_excel('zakat_y.xlsx', index=False)
